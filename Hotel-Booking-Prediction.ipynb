# %% [markdown]
# # Hotel Booking Dataset-Machine Learning

# %% [markdown]
# ### Data loading and Summary

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('hotel_bookings.csv')

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# ### Data Preprocessing and cleaning

# %% [markdown]
# #### Missing Data Handling

# %%
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
df.shape
# Out:
# (119390, 32)

# %%
df['children'] = df['children'].fillna(0)
df['country'] = df['country'].fillna('Unknown')
df['agent'] = df['agent'].fillna(0)
df['company'] = df['company'].fillna(0)

# %%
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# company                           0
# days_in_waiting_list              0
# ...

# %% [markdown]
# #### Outlier Treatment

# %%
outlier_cols = [
    "adr",
    "lead_time",
    "stays_in_weekend_nights",
    "stays_in_week_nights",
]

plt.figure(figsize=(16, 12))


for i, col in enumerate(outlier_cols, 1):
    plt.subplot(2,2, i) 
    sns.boxplot(x=df[col])
    plt.title(col+" Before outlier treatment")

plt.tight_layout()
plt.show()

# %%
def cap_outliers_iqr(df, col):
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    df[col] = np.where(df[col] > upper_bound, upper_bound,
               np.where(df[col] < lower_bound, lower_bound, df[col]))
    return df


for i in outlier_cols:
    df = cap_outliers_iqr(df, i)

# %%
plt.figure(figsize=(16,12))

for i, col in enumerate(outlier_cols, 1):
    plt.subplot(2,2, i) 
    sns.boxplot(x=df[col])
    plt.title(col+" After Outlier Treatment")

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Datatype Conversions

# %%
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'])

# %% [markdown]
# ### Feature Engineering

# %% [markdown]
# #### Categorical Grouping

# %%
def lead_time_category(x):
    if x < 30: return "Short"
    elif x < 90: return "Medium"
    else: return "Long"

df['lead_time_group'] = df['lead_time'].apply(lead_time_category)

# %%
df[['lead_time','lead_time_group']].sample(3)
# Out:
#         lead_time lead_time_group
# 12014        20.0           Short
# 111182        0.0           Short
# 80966         1.0           Short

# %% [markdown]
# ### Complex and advanced Functions

# %% [markdown]
# #### Running Total Analysis

# %%
df['arrival_date'] = pd.to_datetime(
    df['arrival_date_year'].astype(str) + '-' +
    df['arrival_date_month'] + '-' +
    df['arrival_date_day_of_month'].astype(str),
    format='%Y-%B-%d'
)

# %%
df = df.sort_values('arrival_date')

df['cumulative_cancellations'] = df['is_canceled'].cumsum()

# %%
df[['arrival_date','cumulative_cancellations']].head(50)
# Out:
#       arrival_date  cumulative_cancellations
# 0       2015-07-01                         0
# 75559   2015-07-01                         0
# 75560   2015-07-01                         0
# 75561   2015-07-01                         0
# 75562   2015-07-01                         0
# 75563   2015-07-01                         0
# 75564   2015-07-01                         0
# 75565   2015-07-01                         0
# 75566   2015-07-01                         0
# 75558   2015-07-01                         0
# 75567   2015-07-01                         0
# 75569   2015-07-01                         0
# 75570   2015-07-01                         0
# 75571   2015-07-01                         0
# 75572   2015-07-01                         0
# 75573   2015-07-01                         0
# 75574   2015-07-01                         0
# 75575   2015-07-01                         0
# 75576   2015-07-01                         0
# 75568   2015-07-01                         0
# ...

# %%
plt.figure(figsize=(12,6))
plt.plot(df['arrival_date'], df['cumulative_cancellations'], color='red')
plt.title("Running Total of Booking Cancellations Over Time", fontsize=14)
plt.xlabel("Date")
plt.ylabel("Cumulative Cancellations")
plt.show()

# %% [markdown]
# #### Weighted Booking Score

# %%
df['weighted_score'] = ((df['previous_cancellations'] + 1) /
                        (df['previous_cancellations'] + df['previous_bookings_not_canceled'] + 1))

# %%
df[['previous_cancellations','previous_bookings_not_canceled','weighted_score']].sample(4)
# Out:
#        previous_cancellations  previous_bookings_not_canceled  weighted_score
# 43858                       0                               0             1.0
# 33651                       0                               0             1.0
# 91678                       0                               0             1.0
# 95987                       0                               0             1.0

# %% [markdown]
# #### Dynamic Rank Calculation

# %%
hotel_cancel_rate = df.groupby('hotel')['is_canceled'].mean()

hotel_ranking = hotel_cancel_rate.rank(ascending=True).astype(int)

df['hotel_rank'] = df['hotel'].map(hotel_ranking)


print("Cancellation Rates with Rankings:")
print(pd.DataFrame({
    'Cancellation Rate': hotel_cancel_rate,
    'Rank': hotel_ranking
}).sort_values('Rank'))


print("\nSample data with hotel_rank column:")
display(df[['hotel', 'is_canceled', 'hotel_rank']].sample(5))
# Out:
# Cancellation Rates with Rankings:
#               Cancellation Rate  Rank
# hotel
# Resort Hotel           0.277634     1
# City Hotel             0.417270     2
#
# Sample data with hotel_rank column:
#               hotel  is_canceled  hotel_rank
# 48802    City Hotel            1           2
# 27030  Resort Hotel            0           1
# 65901    City Hotel            1           2
# 86609    City Hotel            0           2
# 24558  Resort Hotel            0           1

# %% [markdown]
# ### Advanced Filtering And Parameterized Visualizations

# %% [markdown]
# #### Dynamic Market Segment Analysis

# %%
df['market_segment'].value_counts()
# Out:
# Online TA        56477
# Offline TA/TO    24219
# Groups           19811
# Direct           12606
# Corporate         5295
# Complementary      743
# Aviation           237
# Undefined            2
# Name: market_segment, dtype: int64

# %%
def analyze_market_segment(segment):
    temp = df[df['market_segment'] == segment]
    print(f"Total bookings in {segment}: {len(temp)}")
    print(f"Cancellation rate in {segment}: {temp['is_canceled'].mean():.2f}")
    display(temp.sample(5))
    
    temp['is_canceled'].value_counts(normalize=True).plot(
        kind='bar', color=['skyblue','tomato'], figsize=(5,3), title=f"Cancellation Distribution - {segment}"
    )

analyze_market_segment("Online TA")
# Out:
# Total bookings in Online TA: 56477
# Cancellation rate in Online TA: 0.37
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 104562    City Hotel            0       61.0               2017
# 31770   Resort Hotel            0        0.0               2017
# 101253    City Hotel            0      107.0               2016
# 8943    Resort Hotel            1      110.0               2016
# 71161     City Hotel            1      103.0               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 104562            January                         3
# 31770             January                         1
# 101253           November                        46
# 8943              October                        43
# 71161                June                        26
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 104562                         16                      1.0
# 31770                           6                      0.0
# ...

# %% [markdown]
# #### Find High-Risk Customers

# %%
high_risk = (df[df['previous_cancellations'] > 1][['customer_type','previous_cancellations','previous_bookings_not_canceled']]
             .drop_duplicates().sort_values('previous_cancellations', ascending=False))


display(high_risk)
# Out:
#          customer_type  previous_cancellations  previous_bookings_not_canceled
# 14785        Transient                      26                               0
# 14853        Transient                      25                               0
# 14989        Transient                      24                               0
# 15173  Transient-Party                      24                               0
# 73714  Transient-Party                      21                               0
# ...                ...                     ...                             ...
# 76675        Transient                       2                              20
# 89367        Transient                       2                              14
# 89368  Transient-Party                       2                              15
# 76674        Transient                       2                              19
# 73874         Contract                       2                               0
#
# [155 rows x 3 columns]

# %%
plt.figure(figsize=(8,4))
plt.bar(high_risk['customer_type'], high_risk['previous_cancellations'], color="Red")
plt.title("High-Risk Customers by Previous Cancellations")
plt.xlabel("Customer Type")
plt.ylabel("Number of Previous Cancellations")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### Most Frequent Guests

# %%
frequent_guests = df[df['is_repeated_guest'] == 1]['customer_type'].value_counts()

print("Most frequent guest types:")
print(frequent_guests)

frequent_guests.plot(kind='bar', figsize=(5,3), color='green', title="Most Frequent Guest Types")
# Out:
# Most frequent guest types:
# Transient          3073
# Transient-Party     543
# Group               161
# Contract             33
# Name: customer_type, dtype: int64
# <AxesSubplot:title={'center':'Most Frequent Guest Types'}>

# %% [markdown]
# #### Seasonal Booking Trends

# %%
monthly_bookings = df.groupby('arrival_date_month').size()


monthly_bookings.plot(kind='bar', figsize=(10,4), color='skyblue', title="Total Bookings per Month")
plt.show()


monthly_hotel_trends = df.groupby(['arrival_date_month','hotel']).size().unstack()

monthly_hotel_trends.plot(kind='line', marker='o', figsize=(10,5), title="Monthly Booking Trends by Hotel")
plt.show()

# %% [markdown]
# ### Joins And Multi-Table Queries

# %% [markdown]
# #### Hotel-Specific Cancellation Rate

# %%
hotel_cancel_summary = df.groupby('hotel').agg(
    total_bookings=('is_canceled','count'),
    total_cancellations=('is_canceled','sum'),
    cancellation_rate=('is_canceled','mean')
).reset_index()

hotel_cancel_summary
# Out:
#           hotel  total_bookings  total_cancellations  cancellation_rate
# 0    City Hotel           79330                33102           0.417270
# 1  Resort Hotel           40060                11122           0.277634

# %%
plt.figure(figsize=(6,4))
plt.bar(hotel_cancel_summary['hotel'], hotel_cancel_summary['cancellation_rate'], color='orange')
plt.title("Cancellation Rate per Hotel")
plt.ylabel("Rate")
plt.show()

# %% [markdown]
# #### Countries With High Cancellation Rates

# %%
country_cancel_summary = df.groupby('country').agg(
    total_bookings=('is_canceled','count'),
    total_cancellations=('is_canceled','sum'),
    cancellation_rate=('is_canceled','mean')
).reset_index()

country_cancel_summary = country_cancel_summary[country_cancel_summary['total_bookings'] > 100]


country_cancel_summary = country_cancel_summary.sort_values('cancellation_rate', ascending=False)

country_cancel_summary.head(10)
# Out:
#     country  total_bookings  total_cancellations  cancellation_rate
# 135     PRT           48590                27519           0.566351
# 1       AGO             362                  205           0.566298
# 31      CHN             999                  462           0.462462
# 103     MAR             259                  109           0.420849
# 91      KOR             133                   55           0.413534
# 162     TUR             248                  102           0.411290
# 100     LUX             287                  109           0.379791
# 140     RUS             632                  239           0.378165
# 25      BRA            2224                  830           0.373201
# 81      ITA            3766                 1333           0.353956

# %%
top_countries = country_cancel_summary.head(10)

plt.figure(figsize=(10,5))
plt.bar(top_countries['country'], top_countries['cancellation_rate'], color='tomato')
plt.title("Top 10 Countries by Cancellation Rate")
plt.ylabel("Cancellation Rate")
plt.xlabel("Country")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Feature Engineering,Scaling and Model Building

# %%
df['total_guests'] = df['adults'] + df['children'] + df['babies']

df['total_nights'] = df['stays_in_weekend_nights'] + df['stays_in_week_nights']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 119390 entries, 0 to 117424
# Data columns (total 39 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  float64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  category
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  float64
#  8   stays_in_week_nights            119390 non-null  float64
#  9   adults                          119390 non-null  int64
#  10  children                        119390 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

num_cols = [
    'previous_cancellations','previous_bookings_not_canceled','booking_changes',
    'agent','company','days_in_waiting_list','adr','required_car_parking_spaces',
    'total_of_special_requests','weighted_score','total_guests','total_nights','hotel_rank','cumulative_cancellations'
]

cat_cols = [
    'hotel','arrival_date_year','arrival_date_month','arrival_date_week_number',
    'arrival_date_day_of_month','meal','country','market_segment','assigned_room_type','distribution_channel',
    'reserved_room_type','deposit_type','customer_type','lead_time_group'
]


preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), num_cols),
        ('cat', OneHotEncoder(handle_unknown='ignore',drop='first'), cat_cols)
    ]
)

# %% [markdown]
# #### Splitting Dataset

# %%
from sklearn.model_selection import train_test_split

x = df[num_cols + cat_cols]
y = df['is_canceled']

x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42, stratify=y
)

# %%
x_train.columns
# Out:
# Index(['previous_cancellations', 'previous_bookings_not_canceled',
#        'booking_changes', 'agent', 'company', 'days_in_waiting_list', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'weighted_score', 'total_guests', 'total_nights', 'hotel_rank',
#        'cumulative_cancellations', 'hotel', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'meal', 'country', 'market_segment',
#        'assigned_room_type', 'distribution_channel', 'reserved_room_type',
#        'deposit_type', 'customer_type', 'lead_time_group'],
#       dtype='object')

# %% [markdown]
# #### Model Building

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import LinearSVC

models = {
    'Logistic Regression': LogisticRegression(max_iter=1000, solver='saga', random_state=42),
    'Decision Tree': DecisionTreeClassifier(max_depth=5, random_state=42),
    'Random Forest': RandomForestClassifier(n_estimators=50, max_depth=8, random_state=42, n_jobs=-1),
    'Gradient Boosting': GradientBoostingClassifier(n_estimators=50, learning_rate=0.1, max_depth=3, random_state=42),
    'Linear SVC':LinearSVC(C=1.0,max_iter=5000,random_state=42)
}


param_grid = {
    'Logistic Regression': {'model__C':[0.5, 1]},
    'Decision Tree': {'model__max_depth':[5,7], 'model__min_samples_split':[5,10]},
    'Random Forest': {'model__n_estimators':[100,150], 'model__max_depth':[10,12]},
    'Gradient Boosting': {'model__n_estimators':[100,150], 'model__learning_rate':[0.5, 0.1]},
     'Linear SVC': {'model__C': [0.7, 1.0],'model__max_iter': [4000, 5000]}
    
}

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
import pandas as pd

results = []

for name, model in models.items():
    
    pipe = Pipeline(steps=[('preprocess', preprocessor), ('model', model)])
    
    pipe.fit(x_train, y_train)
    
    y_pred = pipe.predict(x_test)
    y_prob = pipe.predict_proba(x_test)[:, 1] if hasattr(pipe, "predict_proba") else pipe.decision_function(x_test)
   
    acc = accuracy_score(y_test, y_pred)
    prec = precision_score(y_test, y_pred)
    rec = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    auc = roc_auc_score(y_test, y_prob)

    results.append([name, acc, prec, rec, f1, auc])

results_df = pd.DataFrame(results, columns=["Model", "Accuracy", "Precision", "Recall", "F1", "AUC"])
print(results_df)
# Out:
#                  Model  Accuracy  Precision    Recall        F1       AUC
# 0  Logistic Regression  0.826786   0.813808  0.690334  0.747003  0.902293
# 1        Decision Tree  0.803669   0.842591  0.577954  0.685622  0.867512
# 2        Random Forest  0.778792   0.971172  0.415150  0.581657  0.901898
# 3    Gradient Boosting  0.834534   0.846601  0.675749  0.751588  0.914606
# 4           Linear SVC  0.825446   0.816484  0.682080  0.743255  0.900675

# %% [markdown]
# #### Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

best_models = {}

for name, model in models.items():
    pipe = Pipeline(steps=[('preprocess', preprocessor), ('model', model)])
    
    grid = GridSearchCV(pipe, param_grid[name], cv=5, scoring='f1', n_jobs=-1)
    grid.fit(x_train, y_train)
    
    best_models[name] = grid.best_estimator_
    print(f"{name} best params: {grid.best_params_}")
# Out:
# Logistic Regression best params: {'model__C': 1}
# Decision Tree best params: {'model__max_depth': 7, 'model__min_samples_split': 10}
# Random Forest best params: {'model__max_depth': 12, 'model__n_estimators': 150}
# Gradient Boosting best params: {'model__learning_rate': 0.5, 'model__n_estimators': 150}
# Linear SVC best params: {'model__C': 0.7, 'model__max_iter': 4000}

# %%
results = []

for name, model in best_models.items():
    y_pred = model.predict(x_test)
    y_proba = model.predict_proba(x_test)[:,1] if hasattr(pipe, "predict_proba") else pipe.decision_function(x_test)
    
    results.append({
        'Model': name,
        'Accuracy': accuracy_score(y_test, y_pred),
        'Precision': precision_score(y_test, y_pred),
        'Recall': recall_score(y_test, y_pred),
        'F1': f1_score(y_test, y_pred),
        'AUC': roc_auc_score(y_test, y_proba)
    })

results_df = pd.DataFrame(results)
print(results_df)
# Out:
#                  Model  Accuracy  Precision    Recall        F1       AUC
# 0  Logistic Regression  0.826786   0.813808  0.690334  0.747003  0.900675
# 1        Decision Tree  0.825990   0.805737  0.698700  0.748411  0.900675
# 2        Random Forest  0.810495   0.953591  0.513397  0.667451  0.900675
# 3    Gradient Boosting  0.871849   0.853909  0.789033  0.820190  0.900675
# 4           Linear SVC  0.825404   0.816545  0.681854  0.743146  0.900675

# %% [markdown]
# #### Model Testing using Cross-Validation

# %%
from sklearn.model_selection import cross_validate


scoring = ['accuracy', 'precision', 'recall', 'f1', 'roc_auc']

results = {}

for name, model in models.items():
    pipe = Pipeline(steps=[('preprocess', preprocessor), ('model', model)])
    
    cv_results = cross_validate(
        pipe, x, y, cv=5, scoring=scoring, return_train_score=False
    )
    
    results[name] = {
        "Accuracy": cv_results['test_accuracy'].mean(),
        "Precision": cv_results['test_precision'].mean(),
        "Recall": cv_results['test_recall'].mean(),
        "F1": cv_results['test_f1'].mean(),
        "AUC": cv_results['test_roc_auc'].mean()
    }

results_df = pd.DataFrame(results).T
print(results_df)
# Out:
#                      Accuracy  Precision    Recall        F1       AUC
# Logistic Regression  0.788148   0.756594  0.660797  0.695994  0.868697
# Decision Tree        0.721317   0.723793  0.651457  0.652697  0.758757
# Random Forest        0.773700   0.921437  0.446095  0.583299  0.877297
# Gradient Boosting    0.756529   0.765373  0.694013  0.688969  0.888748
# Linear SVC           0.752123   0.673337  0.710320  0.673703  0.855998

# %% [markdown]
# ### Model Selection
#
# By Using the Cross Validation and Grid SearchCV , the best model for this hotel booking dataset can be "Gradient boosting".
# Here,Logistic regression gave good accuracy in cross validation,but by comparing precision,recall and AUC,Gradient boosting is the Best.Also in Grid SearchCv,Gradient boosting gave 87% Accuracy,which is quite good.
#
# So,I think "Gradient boosting"(87% accuracy)is best and after that "Logistic Regression"(82% accuracy) is the best model
